# <br>source: <a href="https://adaa.org/understanding-anxiety/related-illnesses/other-related-conditions/stress/physical-activity-reduces-st">https://adaa.org/understanding-anxiety/related-illnesses/other-related-conditions/stress/physical-activity-reduces-st</a>
#
# <br>(2)Books
# <br>According to a research, it shows that stress levels were shown to be reduced by 68 percent after reading.
# <br>source: <a href="https://www.mondaycampaigns.org/destress-monday/reading-fiction-stress-relief">https://www.mondaycampaigns.org/destress-monday/reading-fiction-stress-relief</a>
#
# <br>(3)Quotes
# <br>The Science Behind Why Inspirational Quotes Motivate Us.
# <br>source: <a href="https://www.fastcompany.com/3051432/why-inspirational-quotes-motivate-us">https://www.fastcompany.com/3051432/why-inspirational-quotes-motivate-us</a>
#
# <br>(4)Online Therapy
# <br>According to a study, As many as 98% of people have reported that they find online counseling is much more convenient than regular therapy. And 88% of people have reported that online therapy is much more affordable than traditional counseling when done over a 4-month period.
# <br>source: <a href="https://www.medgadget.com/2020/02/online-therapy-leading-among-all-telehealth-services.html">https://www.medgadget.com/2020/02/online-therapy-leading-among-all-telehealth-services.html</a>
#
# <br>(5)Meditation - the rising of a wellness app named Calm
# <br>Calm had 2 million paid subscribers in 2019. And by 2019 it had more than 80 million downloads and 92 million USD in revenue.
# <br>source: <a href="https://qz.com/1934906/meditation-app-calm-is-booming-in-anxious-times/">https://qz.com/1934906/meditation-app-calm-is-booming-in-anxious-times/</a>

# %% [markdown]
# <br>
# <br>
# <h1>Data Scrapping</h1>
# <h2>books related to the topic of 'Self Care' from amazon.com</h2>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('/Users/sammy/Documents/data/chromedriver')
def url(serach):
    template = "https://www.amazon.com/s?k={}&qid=1633797653&ref=sr_pg_1"
    search = serach.replace(' ', '+')
    return template.format(search)
url = url("self love")
print(url)

driver.get(url)
html = driver.page_source
soup = BeautifulSoup(html)
results = soup.find_all("div", attrs={"class":"a-section a-spacing-medium"})
len(results)
# Out:
# https://www.amazon.com/s?k=self+love&qid=1633797653&ref=sr_pg_1
# 49

# %%
records = []
results = soup.find_all("div", attrs={"class":"a-section a-spacing-medium"})

for item in results:
    record = extract_record(item)
    if record:
        records.append(record)

# %%
def extract_record(item):
    #item
    atag = item.h2.a
    name = atag.text.strip()
    url = "https://www.amazon.com/" + atag.get('href')
    
    #price
    try:
        price_parent = item.find('span','a-price')
        price = price_parent.find('span','a-offscreen').text
    except AttributeError:
        return
        
    #rating
    try:
        rating = item.i.text
    except AttributeError:
        rating = ''
    
    #format
    formats = item.find('div','a-row a-size-base a-color-base').text
    
    result = (name, price, formats, rating, url)
    
    return result

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver

def generate_url(search_term, page):
    base_template = 'https://www.amazon.com/s?k={}&ref=nb_sb_noss_1'
    search_term = search_term.replace(' ', '+')
    stem = base_template.format(search_term)
    url_template = stem + '&page={}'
    if page == 1:
        return stem
    else:
        return url_template.format(page)

def main(search):
    driver = webdriver.Chrome('/Users/sammy/Documents/data/chromedriver')
    records = []
    url = get_url(search)
    
    for page in range(1,8):
        search_url = generate_url(search, page)
        driver.get(search_url)
        
        html = driver.page_source
        soup = BeautifulSoup(html)
        results = soup.find_all("div", attrs={"class":"a-section a-spacing-medium"})
        
        for item in results:
            record = extract_record(item)
            if record:
                records.append(record)
                
    driver.close()
    
    with open('results.csv', 'w', newline='', encoding='utf-8')as f:
        writer = csv.writer(f)
        writer.writerow(['Name', 'Price', 'Format', 'Rating', 'URL'])
        writer.writerows(records)

# %%
main('self love')

# %% [markdown]
# <br>
# <br>
# <h1>Data Cleaning</h1>
# <h2>dealing with the missing information</h2>
# <br>
# <h2>**the final version of CSV file is located in the 'assignment_4' file, please check it out :)</h2>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("results.csv")
df
# Out:
#                                                   Name   Price  \
# 0    Self-Love Workbook for Women: Release Self-Dou...   $9.59
# 1    The Self-Love Workbook: A Life-Changing Guide ...  $14.10
# 2             Self Love Poetry: For Thinkers & Feelers  $13.49
# 3    Unconditional: You Are Perfect As You Are: Man...  $12.99
# 4                   What The Heck Is Self-Love Anyway?  $11.72
# ..                                                 ...     ...
# 281             Love Yourself, Heal Your Life Workbook  $13.68
# 282  Why I Love Superman & Other Superheroes: One V...   $2.99
# 283                                    Unsent Messages   $0.00
# 284                  You Can Thank Me Later: A Novella   $0.00
# 285  Avery's Garden Coloring Book and Creative Grie...  $18.95
#
#                  Format              Rating  \
# 0            Paperback   4.7 out of 5 stars
# 1            Paperback   4.6 out of 5 stars
# 2            Paperback   4.8 out of 5 stars
# ...

# %%
# df.isnull()
df.isnull().sum()
# Out:
# Name      0
# Price     0
# Format    0
# Rating    0
# URL       0
# dtype: int64

# %%
# df.isnull().Rating

# %%
df[df['Rating'].isnull()]
# Out:
#                                                   Name   Price  \
# 30   Self-Love Workbook for Men: Recognize Your Wor...   $0.00
# 46   30 Days of Self-Love: A guided journal for sel...  $14.99
# 67   The Self-Love Song: A Guide to Breaking Cycles...  $18.95
# 68   Guided Meditations for Deep Sleep, Self-Love &...   $0.00
# 75   Self-Love Workbook Giant 30 Day Challenge for ...  $14.95
# 85   Life Begins at the End of your Comfort Zone: 7...  $10.99
# 86   It's Time To Love Journal: Empower self-love b...  $12.99
# 92   Angelic Channeled Messages: Self-Love, Abundan...   $0.00
# 104                          Self-Love and Mindfulness  $17.00
# 109  30 Day Self Love and Affirmations Prompt Journ...   $9.99
# 116  A Year of Self-Love Page-A-Day Calendar 2022: ...  $14.16
# 125  Self Love Journal: 30 Day Guided Journal to Se...  $17.88
# 128                   My Self-Love ABC's Coloring Book   $8.00
# 133  Positive Affirmations for Black Women: Over 10...   $0.00
# ...

# %%
df = df[:].fillna(0)
df
# Out:
#                                                   Name   Price  \
# 0    Self-Love Workbook for Women: Release Self-Dou...   $9.59
# 1    The Self-Love Workbook: A Life-Changing Guide ...  $14.10
# 2             Self Love Poetry: For Thinkers & Feelers  $13.49
# 3    Unconditional: You Are Perfect As You Are: Man...  $12.99
# 4                   What The Heck Is Self-Love Anyway?  $11.72
# ..                                                 ...     ...
# 281             Love Yourself, Heal Your Life Workbook  $13.68
# 282  Why I Love Superman & Other Superheroes: One V...   $2.99
# 283                                    Unsent Messages   $0.00
# 284                  You Can Thank Me Later: A Novella   $0.00
# 285  Avery's Garden Coloring Book and Creative Grie...  $18.95
#
#                  Format              Rating  \
# 0            Paperback   4.7 out of 5 stars
# 1            Paperback   4.6 out of 5 stars
# 2            Paperback   4.8 out of 5 stars
# ...

# %%
df.to_csv('results.csv')
